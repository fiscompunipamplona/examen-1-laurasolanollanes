# %%
#Laura Solano LLanes
#Johan Mantilla
from numpy import loadtxt
from pylab import xlim, ylim, grid, savefig, xlabel, ylabel, show, plot



datasunspots = loadtxt("sunspots.txt", float)
plot(datasunspots[:,0], datasunspots[:,1])
plot(datasunspots[:,0], datasunspots[:,1])
grid("on")
savefig('figura1: Meses vs Manchas)', format='eps', dpi=1000)
xlabel("Meses")
ylabel("Numero Manchas")
show()

# %%
from numpy import loadtxt
from pylab import xlim, ylim, grid, savefig, xlabel, ylabel, show, plot

a=loadtxt("punto1b.txt",float)
#print(a)
datasunspots = loadtxt("punto1b.txt", float)
plot(datasunspots[:,0], datasunspots[:,1])
plot(datasunspots[:,0], datasunspots[:,1])
grid("on")
savefig('figura1: Meses vs Manchas)', format='eps', dpi=1000)
xlabel("Meses")
ylabel("Numero Manchas")
show()

# %%
from numpy import loadtxt
from pylab import xlim, ylim, grid, savefig, xlabel, ylabel, show, plot
a=loadtxt("prom.txt",float)
sum=0.0
sum2=0.0
datos=[]

for i in range (0,5):
    sum=sum + a[i]
    y=(sum/(5))
print(y)
for i in range (5,1000):
    sum2=sum2+a[i]
    x=(sum2/i)
    print(x)
# Out:
# 81.1
# 15.1
# 39.0166666667
# 45.6142857143
# 49.075
# 52.0555555556
# 55.77
# 58.7272727273
# 61.3333333333
# 64.3076923077
# 65.8142857143
# 68.2933333333
# 69.725
# 69.4882352941
# 69.1444444444
# 69.4736842105
# 69.5
# 68.2619047619
# 67.2181818182
# 66.747826087
# 66.4958333333
# 65.864
# 65.8807692308
# 65.6555555556
# 64.15
# 62.7379310345
# 61.5966666667
# 61.0290322581
# 60.215625
# 59.9060606061
# 60.2323529412
# 60.2057142857
# 60.1916666667
# 59.6351351351
# 60.1289473684
# 59.3384615385
# 58.5325
# 58.2414634146
# 57.75
# 57.3372093023
# 57.0340909091
# 56.4777777778
# 56.2434782609
# 55.8553191489
# 55.4416666667
# 54.9571428571
# 54.298
# 53.9980392157
# 53.4980769231
# 52.9603773585
# 52.35
# 51.52
# 50.6
# 49.7649122807
# 48.9362068966
# 48.3389830508
# 47.8783333333
# 47.531147541
# 47.0677419355
# 46.5158730159
# 45.9171875
# 45.5815384615
# 45.0909090909
# 44.4805970149
# 43.9764705882
# 43.5014492754
# 42.9771428571
# 42.4633802817
# 41.8736111111
# 41.3
# ...

# %%
from numpy import loadtxt
from pylab import xlim, ylim, grid, savefig, xlabel, ylabel, show, plot

#a=loadtxt("punto1b.txt",float)
#a=loadtxt("nuevodato.txt",float)



datasunspots = loadtxt("punto1b.txt", float)
datanuevodato = loadtxt("datos.txt", float)
plot(datasunspots[:,0], punto1b[:,1])
plot(datasunspots[:,0], punto1b[:,1])

#datanuevodato=loadtxt("nuevodato.txt", float)
plot(datanuevodato[:,0], datanuevodato[:,1])
#plot(datanuevodato[:,0], datanuevodato[:,1])
#grid("on")
#savefig('figura1: Meses vs Manchas)', format='eps', dpi=1000)
#xlabel("Meses")
#ylabel("Numero Manchas")


grid("on")
savefig('figura1: Meses vs Manchas)', format='eps', dpi=1000)
xlabel("Meses")
ylabel("Numero Manchas")
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-bf1729291b5c> in <module>()
#       9 datasunspots = loadtxt("punto1b.txt", float)
#      10 datanuevodato = loadtxt("datos.txt", float)
# ---> 11 plot(datasunspots[:,0], punto1b[:,1])
#      12 plot(datasunspots[:,0], punto1b[:,1])
#      13
#
# NameError: name 'punto1b' is not defined
